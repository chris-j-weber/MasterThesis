# %% [markdown]
# <a href="https://colab.research.google.com/github/chris-j-weber/MasterThesis/blob/main/Create_Audio_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convert Video Files (.mp4) to Audio Files (.wav)

# %%
#@title Initialize and download datasets
import os
import os.path

# !rm -rf sample_data/
if not os.path.isfile('mmsd_raw_data.zip'):
  # !gdown --id 1i9ixalVcXskA5_BkNnbR60sqJqvGyi6E

if not os.path.isfile('ger_context.zip'):
  # !gdown --id 12rdD3tt8QEeZqHvKeFJ20qLO6Kf0x09L

if not os.path.isfile('ger_utterances.zip'):
  # !gdown --id 1CHXdx8Oze-mpozCve9DLekFhsOzLhQ49

if not os.path.isdir('/content/mmsd_raw_data'):
  # !unzip -qq mmsd_raw_data.zip -d /content/mmsd_raw_data
  # !rm -rf /content/mmsd_raw_data/__MACOSX/
  # !rm -rf mmsd_raw_data.zip

if not os.path.isdir('/content/germanAudio'):
  # !unzip -qq ger_utterances.zip -d /content/germanAudio
  # !unzip -qq ger_context.zip -d /content/germanAudio
  # !rm -rf ger_utterances.zip
  # !rm -rf ger_context.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1i9ixalVcXskA5_BkNnbR60sqJqvGyi6E
# To: /content/mmsd_raw_data.zip
# 100% 1.40G/1.40G [00:05<00:00, 266MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12rdD3tt8QEeZqHvKeFJ20qLO6Kf0x09L
# To: /content/ger_context.zip
# 100% 787M/787M [00:07<00:00, 105MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CHXdx8Oze-mpozCve9DLekFhsOzLhQ49
# To: /content/ger_utterances.zip
# 100% 302M/302M [00:02<00:00, 142MB/s]

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
from moviepy.editor import *
from IPython.display import HTML, display

def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))

# %%
# !rm -rf /content/audioFiles

# %%
dirlist = ["/content/mmsd_raw_data/utterances_final", "/content/mmsd_raw_data/context_final", "/content/germanAudio/utterances", "/content/germanAudio/context"]
maxstep = sum([len(os.listdir(i)) for i in dirlist])

out = display(progress(0, maxstep), display_id=True)

i = 0
for videoDir in dirlist:
  #output Audio Path
  _, p = os.path.split(videoDir)
  audioDir = "/content/audioFiles/" + p
  os.makedirs(audioDir)

  for filename in os.listdir(videoDir):
    f = os.path.join(videoDir, filename)
    # checking if it is a file
    if os.path.isfile(f) and filename[-3:] == 'mp4':
        audiopath = os.path.join(audioDir, filename[:-4]) + '.wav'
        audioclip = AudioFileClip(f)
        audioclip.write_audiofile(audiopath)
    i += 1
    out.update(progress(i+1, maxstep))
# Out:
#         <progress
#             value='1942'
#             max='1941',
#             style='width: 100%'
#         >
#             1942
#         </progress>
# [MoviePy] Writing audio in /content/audioFiles/utterances_final/1_8746.wav
# 100%|██████████| 199/199 [00:00<00:00, 4473.05it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/audioFiles/utterances_final/1_4743.wav
# 100%|██████████| 266/266 [00:00<00:00, 4396.04it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/audioFiles/utterances_final/1_8052.wav
# 100%|██████████| 177/177 [00:00<00:00, 4004.62it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/audioFiles/utterances_final/2_442.wav
# 100%|██████████| 79/79 [00:00<00:00, 3651.16it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/audioFiles/utterances_final/2_604.wav
# 100%|██████████| 83/83 [00:00<00:00, 4570.22it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/audioFiles/utterances_final/2_576.wav
# ...

# %% [markdown]
# # Create Audio Features from wav Files

# %% [markdown]
# # Convert Audio Files to Mel Scale Spectogram and MFCC

# %%
#@title Imports
# !pip install --upgrade keras

# !pip install speechpy
import os
import librosa
import speechpy
import numpy as np
from shutil import copyfile
import tensorflow as tf
from tensorflow.python.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

#from keras.layers import CuDNNLSTM
from sklearn.model_selection import train_test_split

# Load the TensorBoard notebook extension
# %load_ext tensorboard
import datetime
# Clear any logs from previous runs
# !rm -rf ./logs/

np.random.seed(42)
tf.random.set_seed(42)

# !git clone https://github.com/chris-j-weber/sarcasmdetection

#!mkdir utils/
# !mv sarcasmdetection/utils/ utils/
# !rm -rf sarcasmdetection
from utils.data_reader import *
# Out:
# ...
# Cloning into 'sarcasmdetection'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 99 (delta 45), reused 66 (delta 22), pack-reused 0
# Unpacking objects: 100% (99/99), done.

# %%
from utils.data_reader import *

mustard_path = "sarcasm_data.json"

if not os.path.isfile(mustard_path):
  # !wget -qq https://raw.githubusercontent.com/soujanyaporia/MUStARD/master/data/sarcasm_data.json

#mustard_path = './sarcasm_data.json'
mustard_data = read_mustard(mustard_path).drop(['context', 'speaker'], axis=1)

list_id = mustard_data.id
list_label = mustard_data.is_sarcastic
id_with_label = {list_id[i]: list_label[i] for i in range(len(list_id))}

id_with_features = {}

# %%
#@title important Methods

n_mfcc = 283


loss_function = BinaryCrossentropy()
optimizer = Adam(learning_rate=1e-5, decay=1e-6)

def preprocess_audio_file(filepath,
                          n_mfcc=n_mfcc,
                          raw_audio=False,
                          spectogram=False):
    """
    Preprocess audio file

    :param filepath: path to .wav-file
    :param n_mfcc: Number of mfcc features to take for each frame (e.g., for RNN)
    :param raw_audio: Whether to return raw audio signal (e.g., for Conv1D neural network)
    :param spectogram: Whether to return a melspectogram (e.g., for Conv2D neural network)

    :return feature vector from mfcc
    """
    # step 2
    signal, sr = librosa.load(path=filepath, sr=22050)
    s_len = len(signal)

    # empirically calculated mean length for the given data set (2 seconds)
    mean_signal_length = 44100  # 22050 * 2 seconds = 44kHz

    # pad/slice the signals to have same size if lesser than required
    if s_len < mean_signal_length:
        pad_len = mean_signal_length - s_len
        pad_rem = pad_len % 2
        pad_len //= 2
        signal = np.pad(signal, (pad_len, pad_len + pad_rem),
                        'constant', constant_values=0)
    else:
        pad_len = s_len - mean_signal_length
        pad_len //= 2
        signal = signal[pad_len:pad_len + mean_signal_length]

    # return raw audio signal
    if raw_audio:
        return signal

    # parameters for STFT
    n_fft = 512
    hop_length = 256
    frame_length = n_fft / sr
    frame_stride = hop_length / sr

    # amount mel bands
    n_mels = 40

    # compute mel scale spectogram
    if spectogram:
        S = librosa.feature.melspectrogram(y=signal,
                                           sr=sr,
                                           n_fft=n_fft,
                                           hop_length=hop_length,
                                           n_mels=n_mels)
        S = librosa.power_to_db(S)
        return S

    # step 3
    # compute MFCCs
    mfccs = speechpy.feature.mfcc(signal=signal,
                                  sampling_frequency=sr,
                                  frame_length=frame_length,
                                  frame_stride=frame_stride,
                                  fft_length=n_fft,
                                  num_filters=n_mels,
                                  num_cepstral=n_mfcc)
    return mfccs


def get_train_test_dataset(path,
                           n_mfcc=n_mfcc,     # in Mustard 283
                           raw_audio=False,
                           spectogram=False):
    """
    Extract data for training and testing.
    """
    data = []  # X
    indexes = []  # y
    id_with_features = {}

    # step 1
    # iterate over audio files and get mfcc feature vector
    list_wavfiles = os.listdir(path)

    for w in list_wavfiles:
      filepath = os.path.join(path, w)
      idx = w[:-4]

      # step 2 + 3
      # shape: (n_windows, n_mfccs)
      feature_vector = preprocess_audio_file(filepath=filepath,
                                              raw_audio=raw_audio,
                                              spectogram=spectogram,
                                              n_mfcc=n_mfcc)
      id_with_features[idx] = feature_vector

    return id_with_features

# %%
import pickle 

def input_output(audioDir, outName, outPath):
  mfcc_dict = get_train_test_dataset(audioDir, spectogram=False)
  melspectrogram_dict = mfcc_dict = get_train_test_dataset(audioDir, spectogram=True)

  pickle_file = open(outPath + outName + '_mfccs.pkl', 'wb') 
  pickle.dump(mfcc_dict, pickle_file)

  pickle_file = open(outPath + outName + '_spect.pkl', 'wb') 
  pickle.dump(melspectrogram_dict, pickle_file)

# %% [markdown]
# # Run Code, Save to Pickle Files and Zip Folder

# %%
outPath = '/content/audioFeatures/'
os.makedirs(outPath)

input_output('/content/audioFiles/context', 'ger_context', outPath)
input_output('/content/audioFiles/utterances', 'ger_utterances', outPath)

input_output('/content/audioFiles/context_final', 'en_context', outPath)
input_output('/content/audioFiles/utterances_final', 'en_utterances', outPath)

# %%
# !zip -r /content/audioFeatures.zip /content/audioFeatures
# Out:
#   adding: content/audioFeatures/ (stored 0%)
#   adding: content/audioFeatures/ger_utterances_mfccs.pkl (deflated 4%)
#   adding: content/audioFeatures/en_context_mfccs.pkl (deflated 4%)
#   adding: content/audioFeatures/en_utterances_spect.pkl (deflated 15%)
#   adding: content/audioFeatures/ger_context_mfccs.pkl (deflated 4%)
#   adding: content/audioFeatures/en_utterances_mfccs.pkl (deflated 7%)
#   adding: content/audioFeatures/ger_utterances_spect.pkl (deflated 12%)
#   adding: content/audioFeatures/en_context_spect.pkl (deflated 12%)
#   adding: content/audioFeatures/ger_context_spect.pkl (deflated 12%)
